# %%
# import sys
# from pathlib import Path
# root_dir = Path().resolve().parent  # goes one level up from `test/`
# sys.path.insert(0, str(root_dir))

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotsense import recommender, plotgen, explainer

# %%
GROQ_API_KEY = os.environ['GROQ_API_KEY']

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111) 
ax1.set_title("Titanic Dataset")
sns.histplot(data=titanic, x="age", ax=ax1)
# Out:
# <Axes: title={'center': 'Titanic Dataset'}, xlabel='age', ylabel='Count'>

# %%
recommendation = recommender(titanic)
recommendation
# Out:
#   plot_type           variables  ensemble_score  model_agreement  \
# 0      hist                 age             1.0                2
# 1       bar    pclass, survived             0.5                1
# 2   boxplot            age, sex             0.5                1
# 3   scatter      fare, survived             0.5                1
# 4       bar  survived, embarked             0.5                1
#
#                                      source_models
# 0  [llama-3.1-8b-instant, llama-3.3-70b-versatile]
# 1                           [llama-3.1-8b-instant]
# 2                           [llama-3.1-8b-instant]
# 3                           [llama-3.1-8b-instant]
# 4                           [llama-3.1-8b-instant]

# %%
fig = plotgen(titanic, 2, recommendation)

# %%
explanation = explainer(fig)
print("Generated Explanation:")
print(explanation)
# Out:
# Generated Explanation:
# ## Explanation of Data Visualization
#
# ### Overview
# The provided data visualization is a bar chart titled "survived by sex," which compares the survival rates of females and males. This chart uses two blue bars to represent the proportion of each gender that survived, with the data likely derived from a historical dataset such as the Titanic passenger data, where survival rates varied significantly by gender.
#
# ### Key Features
# - **Title**: The title "survived by sex" indicates that the chart compares survival rates by gender.
# - **Axes**:
#   - **X-axis**: Represents the gender categories ("female" and "male"). The label "sex" on the x-axis could be considered redundant or misplaced given that the categories are already explicitly labeled as "female" and "male."
#   - **Y-axis**: Represents the proportion of individuals who survived, ranging from 0.0 to 0.7.
# - **Bars**:
#   - The bar for females reaches approximately 0.74 (or 74%), indicating a 74% survival rate.
#   - The bar for males reaches approximately 0.18 (or 18%), indicating an 18% survival rate.
# - **Color Scheme**: Both bars are colored blue, which maintains visual consistency but does not differentiate between genders. Using different colors for each gender could enhance clarity.
#
# ### Insights and Patterns
# - **Survival Rate by Gender**:
#   - Females have a significantly higher survival rate (74%) compared to males (18%).
#   - The survival rate for females is approximately 4.11 times that of males (0.74 / 0.18 ≈ 4.11).
#   - **Confidence Intervals**: To quantify variability, assuming a sample size of 100 for simplicity, the 95% confidence intervals for survival rates could be estimated as follows:
#     - Females: 74% ± √(0.74 * 0.26 / 100) * 1.96 ≈ 74% ± 8.5% or (65.5%, 82.5%)
#     - Males: 18% ± √(0.18 * 0.82 / 100) * 1.96 ≈ 18% ± 7.5% or (10.5%, 25.5%)
# - **Comparison**: The substantial disparity between the survival rates of females and males suggests a strong correlation between gender and survival outcomes.
#
# ### Statistical Insights
# - The difference in survival rates between females and males is statistically significant, as indicated by the large ratio of their survival rates and the non-overlapping confidence intervals.
# - A chi-squared test could be performed to confirm that the observed difference in survival rates is not due to chance.
#
# ### Contextual Considerations
# - The dataset likely pertains to a historical event or a specific context where survival rates were influenced by gender, such as maritime disasters or other emergencies where rescue protocols may prioritize certain groups. A well-known example is the Titanic disaster, where socio-economic status, access to lifeboats, and rescue practices contributed to the observed disparity.
#
# ### Conclusion
# The bar chart clearly illustrates that females had a much higher survival rate than males in the context represented by the data. With females being approximately 4.11 times more likely to survive than males, the data suggests a significant gender disparity. To fully understand this disparity, further analysis should investigate underlying factors such as:
# - Socio-economic status
# - Access to resources during the event
# - Rescue protocols or practices that may have favored one gender over the other
# - Age and familial relationships, which could influence survival rates
#
# Providing context about the dataset and the event or circumstances it represents would be crucial for a deeper understanding of these findings.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
