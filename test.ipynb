# %% [markdown]
# ### Test Jupyter Notebook

# %%
# import sys
# from pathlib import Path
# root_dir = Path().resolve().parent  # goes one level up from `test/`
# sys.path.insert(0, str(root_dir))

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotsense import  recommender, plotgen, explainer

# %%
groq_api_key = os.environ['GROQ_API_KEY']

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111) 
ax1.set_title("Titanic Dataset")
sns.histplot(data=titanic, x="age", ax=ax1)
# Out:
# <Axes: title={'center': 'Titanic Dataset'}, xlabel='age', ylabel='Count'>

# %%
recommendation = recommender(titanic)
recommendation
# Out:
#   plot_type         variables  ensemble_score  model_agreement  \
# 0   scatter         age, fare             1.0                2
# 1      hist               age             1.0                2
# 2       bar  pclass, survived             0.5                1
# 3   boxplot    fare, survived             0.5                1
# 4       pie          embarked             0.5                1
#
#                                      source_models
# 0  [llama-3.1-8b-instant, llama-3.3-70b-versatile]
# 1  [llama-3.1-8b-instant, llama-3.3-70b-versatile]
# 2                           [llama-3.1-8b-instant]
# 3                           [llama-3.1-8b-instant]
# 4                           [llama-3.1-8b-instant]

# %%
fig = plotgen(titanic, 1, recommendation)

# %%
explanation = explainer(fig1)
print("Generated Explanation:")
print(explanation)
# Out:
# Generated Explanation:
# ## Overview
# The histogram illustrates the distribution of ages within the Titanic dataset, providing a visual representation of the count of individuals across different age groups. The dataset comprises a total of approximately 891 passengers, as inferred from the sum of the counts across all age bins. The histogram offers a clear and concise representation of the age demographics of the passengers.
#
# ## Key Features
# * The x-axis represents the age of the passengers, ranging from 0 to 80 years, divided into 5-year intervals (bins).
# * The y-axis represents the count of passengers in each age group, with values ranging from 0 to 100.
# * The histogram is characterized by a peak count of nearly 95 passengers in the 20-25 age range and a total count of approximately 891 passengers across all age groups.
# * Notable features include:
#   - A significant presence of children in the 0-10 age range, with around 40 passengers under the age of 5 and approximately 15 passengers between 5-10 years old.
#   - A substantial number of young adults in the 20-40 age range, with counts consistently above 70 for ages 20-35.
#   - A gradual decline in passenger counts beyond the age of 40, with fewer than 20 passengers above the age of 60.
#
# ## Insights and Patterns
# * **Age Distribution**: The histogram reveals a roughly bell-shaped distribution with a peak in the 20-25 age range, indicating that the majority of passengers were young adults. The distribution is slightly skewed to the right, suggesting a longer tail of older passengers. The mean age is approximately 28 years, with a median age of 26 years, indicating a slight positive skew.
# * **Child and Senior Presence**: The presence of children under 10 years old (around 55 passengers) and the relatively low number of elderly passengers above 60 years (fewer than 30) suggest a lower representation of older adults on the Titanic. Specifically:
#   - Children under 5: approximately 40 passengers
#   - Children between 5-10: approximately 15 passengers
#   - Elderly passengers above 60: approximately 25 passengers
# * **Young Adult Dominance**: The 20-40 age range has the highest concentration of passengers, with counts consistently above 70 for ages 20-35, indicating that young and middle-aged adults constituted a significant portion of the passenger demographic. Specifically:
#   - Ages 20-25: approximately 95 passengers
#   - Ages 25-30: approximately 85 passengers
#   - Ages 30-35: approximately 80 passengers
#
# ## Conclusion
# The histogram provides valuable insights into the age distribution of Titanic passengers, highlighting a predominance of young adults (20-40 years old) and a relatively lower number of children and elderly passengers. With a total of approximately 891 passengers represented, the data indicates a bell-shaped age distribution with a peak in the 20-25 age range. These findings can be crucial for understanding survival patterns, social dynamics, and other demographic analyses related to the Titanic dataset. Further analyses could investigate how the age distribution correlates with survival rates, cabin class, or other relevant factors, providing a more comprehensive understanding of the Titanic's passenger demographics.
